# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir data
# !cd data && wget "http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/extracted_features.npy"
# !cd data && wget "http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/labels.npy"
# !cd data && wget "http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/features_stretched.npy"
# !cd data && wget "http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/labels_stretched.npy"
# Out:
# --2020-12-22 16:59:42--  http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/extracted_features.npy
# Connecting to 164.68.116.174:5000... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126886528 (121M) [application/octet-stream]
# Saving to: ‘extracted_features.npy’
#
# extracted_features. 100%[===================>] 121.01M  6.32MB/s    in 12s
#
# 2020-12-22 16:59:54 (10.4 MB/s) - ‘extracted_features.npy’ saved [126886528/126886528]
#
# --2020-12-22 16:59:54--  http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/labels.npy
# Connecting to 164.68.116.174:5000... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51648 (50K) [application/octet-stream]
# Saving to: ‘labels.npy’
#
# labels.npy          100%[===================>]  50.44K   262KB/s    in 0.2s
#
# 2020-12-22 16:59:55 (262 KB/s) - ‘labels.npy’ saved [51648/51648]
#
# --2020-12-22 16:59:55--  http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/features_stretched.npy
# Connecting to 164.68.116.174:5000... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70063488 (67M) [application/octet-stream]
# Saving to: ‘features_stretched.npy’
#
# features_stretched. 100%[===================>]  66.82M  1.62MB/s    in 24s
#
# 2020-12-22 17:00:19 (2.76 MB/s) - ‘features_stretched.npy’ saved [70063488/70063488]
#
# --2020-12-22 17:00:19--  http://164.68.116.174:5000/download/files/isep/a3/deep-learning/respiratory-sound/labels_stretched.npy
# Connecting to 164.68.116.174:5000... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28576 (28K) [application/octet-stream]
# Saving to: ‘labels_stretched.npy’
#
# labels_stretched.np 100%[===================>]  27.91K  --.-KB/s    in 0.09s
#
# 2020-12-22 17:00:20 (296 KB/s) - ‘labels_stretched.npy’ saved [28576/28576]

# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
origin_features, origin_labels = np.load('/content/data/extracted_features.npy'), np.load('/content/data/labels.npy')
origin_features = np.delete(origin_features, np.where((origin_labels == 'Asthma') | (origin_labels == 'LRTI'))[0], axis=0)
origin_labels = np.delete(origin_labels, np.where((origin_labels == 'Asthma') | (origin_labels == 'LRTI'))[0], axis=0)

# %%
features_stretched, labels_stretched = np.load('/content/data/features_stretched.npy'), np.load('/content/data/labels_stretched.npy')
features_stretched = np.delete(features_stretched, np.where((labels_stretched == 'Asthma') | (labels_stretched == 'LRTI'))[0], axis=0)
labels_stretched = np.delete(labels_stretched, np.where((labels_stretched == 'Asthma') | (labels_stretched == 'LRTI'))[0], axis=0)

# %%
features = np.concatenate((origin_features, features_stretched), axis=0)
labels = np.concatenate((origin_labels,labels_stretched), axis=0)
classes = ['COPD', 'Pneumonia', 'Healthy', 'URTI', 'Bronchiectasis', 'Bronchiolitis']

# %%
le = LabelEncoder()
i_labels = le.fit_transform(labels)
oh_labels = to_categorical(i_labels)

# %%
x_train, x_test, y_train, y_test = train_test_split(features, oh_labels, stratify=oh_labels, test_size=0.2, random_state=42)
num_rows, num_columns, num_channels = 40, 862, 1  # input shape

# %%
num_labels = oh_labels.shape[1]
filter_size = 2

# %%
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 861, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 430, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 430, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 429, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 214, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 214, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 213, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 106, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 106, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 105, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 52, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 52, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 774
# =================================================================
# Total params: 44,086
# Trainable params: 44,086
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
num_epochs = 200
num_batch_size = 128

callbacks = [
    ModelCheckpoint(
        filepath='mymodel2_{epoch:02d}.h5',
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]

# %%
model.fit(np.expand_dims(x_train, axis=3), y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(np.expand_dims(x_test, axis=3), y_test), callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 9s 189ms/step - loss: 7.6027 - accuracy: 0.3423 - val_loss: 2.4261 - val_accuracy: 0.4134
#
# Epoch 00001: val_accuracy improved from -inf to 0.41343, saving model to mymodel2_01.h5
# Epoch 2/200
# 9/9 [==============================] - 1s 71ms/step - loss: 2.6342 - accuracy: 0.5199 - val_loss: 1.6733 - val_accuracy: 0.3887
#
# Epoch 00002: val_accuracy did not improve from 0.41343
# Epoch 3/200
# 9/9 [==============================] - 1s 71ms/step - loss: 1.8172 - accuracy: 0.5334 - val_loss: 1.7042 - val_accuracy: 0.4382
#
# Epoch 00003: val_accuracy improved from 0.41343 to 0.43816, saving model to mymodel2_03.h5
# Epoch 4/200
# 9/9 [==============================] - 1s 70ms/step - loss: 1.2391 - accuracy: 0.5519 - val_loss: 1.5260 - val_accuracy: 0.4735
#
# Epoch 00004: val_accuracy improved from 0.43816 to 0.47350, saving model to mymodel2_04.h5
# Epoch 5/200
# 9/9 [==============================] - 1s 71ms/step - loss: 1.1269 - accuracy: 0.5822 - val_loss: 1.2859 - val_accuracy: 0.5936
#
# Epoch 00005: val_accuracy improved from 0.47350 to 0.59364, saving model to mymodel2_05.h5
# Epoch 6/200
# 9/9 [==============================] - 1s 70ms/step - loss: 1.0376 - accuracy: 0.6144 - val_loss: 1.2716 - val_accuracy: 0.5512
#
# Epoch 00006: val_accuracy did not improve from 0.59364
# Epoch 7/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.9620 - accuracy: 0.6221 - val_loss: 1.2104 - val_accuracy: 0.5901
#
# Epoch 00007: val_accuracy did not improve from 0.59364
# Epoch 8/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.9955 - accuracy: 0.6084 - val_loss: 1.1582 - val_accuracy: 0.6219
#
# Epoch 00008: val_accuracy improved from 0.59364 to 0.62191, saving model to mymodel2_08.h5
# Epoch 9/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.9554 - accuracy: 0.6331 - val_loss: 1.2149 - val_accuracy: 0.5901
#
# Epoch 00009: val_accuracy did not improve from 0.62191
# Epoch 10/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.9770 - accuracy: 0.6212 - val_loss: 1.1482 - val_accuracy: 0.5936
#
# Epoch 00010: val_accuracy did not improve from 0.62191
# Epoch 11/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.9206 - accuracy: 0.6367 - val_loss: 1.0506 - val_accuracy: 0.6360
#
# Epoch 00011: val_accuracy improved from 0.62191 to 0.63604, saving model to mymodel2_11.h5
# Epoch 12/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.9036 - accuracy: 0.6255 - val_loss: 1.0114 - val_accuracy: 0.6749
#
# Epoch 00012: val_accuracy improved from 0.63604 to 0.67491, saving model to mymodel2_12.h5
# Epoch 13/200
# 9/9 [==============================] - 1s 84ms/step - loss: 0.8881 - accuracy: 0.6560 - val_loss: 0.9863 - val_accuracy: 0.6572
#
# Epoch 00013: val_accuracy did not improve from 0.67491
# Epoch 14/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.8486 - accuracy: 0.6713 - val_loss: 0.9581 - val_accuracy: 0.6749
#
# Epoch 00014: val_accuracy did not improve from 0.67491
# Epoch 15/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7920 - accuracy: 0.6829 - val_loss: 0.8597 - val_accuracy: 0.7173
#
# Epoch 00015: val_accuracy improved from 0.67491 to 0.71731, saving model to mymodel2_15.h5
# Epoch 16/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.8138 - accuracy: 0.6663 - val_loss: 0.8363 - val_accuracy: 0.7385
#
# Epoch 00016: val_accuracy improved from 0.71731 to 0.73852, saving model to mymodel2_16.h5
# Epoch 17/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7715 - accuracy: 0.6830 - val_loss: 0.8499 - val_accuracy: 0.7456
#
# Epoch 00017: val_accuracy improved from 0.73852 to 0.74558, saving model to mymodel2_17.h5
# Epoch 18/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.7585 - accuracy: 0.6949 - val_loss: 0.8359 - val_accuracy: 0.7208
#
# Epoch 00018: val_accuracy did not improve from 0.74558
# Epoch 19/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.6941 - accuracy: 0.7335 - val_loss: 0.8203 - val_accuracy: 0.6961
#
# Epoch 00019: val_accuracy did not improve from 0.74558
# Epoch 20/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6650 - accuracy: 0.7506 - val_loss: 0.7892 - val_accuracy: 0.6996
#
# Epoch 00020: val_accuracy did not improve from 0.74558
# Epoch 21/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6724 - accuracy: 0.7362 - val_loss: 0.7366 - val_accuracy: 0.7067
#
# Epoch 00021: val_accuracy did not improve from 0.74558
# Epoch 22/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6722 - accuracy: 0.7442 - val_loss: 0.6885 - val_accuracy: 0.7420
#
# Epoch 00022: val_accuracy did not improve from 0.74558
# Epoch 23/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6270 - accuracy: 0.7568 - val_loss: 0.7178 - val_accuracy: 0.7208
#
# Epoch 00023: val_accuracy did not improve from 0.74558
# Epoch 24/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6394 - accuracy: 0.7451 - val_loss: 0.6693 - val_accuracy: 0.7668
#
# Epoch 00024: val_accuracy improved from 0.74558 to 0.76678, saving model to mymodel2_24.h5
# Epoch 25/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.6379 - accuracy: 0.7470 - val_loss: 0.6892 - val_accuracy: 0.7385
#
# Epoch 00025: val_accuracy did not improve from 0.76678
# Epoch 26/200
# 9/9 [==============================] - 1s 69ms/step - loss: 0.5931 - accuracy: 0.7724 - val_loss: 0.6452 - val_accuracy: 0.7668
#
# Epoch 00026: val_accuracy did not improve from 0.76678
# Epoch 27/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5880 - accuracy: 0.7825 - val_loss: 0.6483 - val_accuracy: 0.7527
#
# Epoch 00027: val_accuracy did not improve from 0.76678
# Epoch 28/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.5636 - accuracy: 0.7886 - val_loss: 0.6516 - val_accuracy: 0.7597
#
# Epoch 00028: val_accuracy did not improve from 0.76678
# Epoch 29/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5829 - accuracy: 0.7748 - val_loss: 0.6423 - val_accuracy: 0.7668
#
# Epoch 00029: val_accuracy did not improve from 0.76678
# Epoch 30/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.5373 - accuracy: 0.8027 - val_loss: 0.6195 - val_accuracy: 0.7739
#
# Epoch 00030: val_accuracy improved from 0.76678 to 0.77385, saving model to mymodel2_30.h5
# Epoch 31/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.5026 - accuracy: 0.8052 - val_loss: 0.5873 - val_accuracy: 0.7845
#
# Epoch 00031: val_accuracy improved from 0.77385 to 0.78445, saving model to mymodel2_31.h5
# Epoch 32/200
# 9/9 [==============================] - 1s 69ms/step - loss: 0.5290 - accuracy: 0.7801 - val_loss: 0.5875 - val_accuracy: 0.7739
#
# Epoch 00032: val_accuracy did not improve from 0.78445
# Epoch 33/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5180 - accuracy: 0.7967 - val_loss: 0.5937 - val_accuracy: 0.7845
#
# Epoch 00033: val_accuracy did not improve from 0.78445
# Epoch 34/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.5206 - accuracy: 0.8038 - val_loss: 0.5770 - val_accuracy: 0.7809
#
# Epoch 00034: val_accuracy did not improve from 0.78445
# Epoch 35/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.5258 - accuracy: 0.8027 - val_loss: 0.5921 - val_accuracy: 0.7845
#
# Epoch 00035: val_accuracy did not improve from 0.78445
# Epoch 36/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.4695 - accuracy: 0.8108 - val_loss: 0.5891 - val_accuracy: 0.7809
#
# Epoch 00036: val_accuracy did not improve from 0.78445
# Epoch 37/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4909 - accuracy: 0.7994 - val_loss: 0.5998 - val_accuracy: 0.7633
#
# Epoch 00037: val_accuracy did not improve from 0.78445
# Epoch 38/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.5480 - accuracy: 0.7937 - val_loss: 0.6230 - val_accuracy: 0.7774
#
# Epoch 00038: val_accuracy did not improve from 0.78445
# Epoch 39/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.5376 - accuracy: 0.7894 - val_loss: 0.6430 - val_accuracy: 0.7845
#
# Epoch 00039: val_accuracy did not improve from 0.78445
# Epoch 40/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.5077 - accuracy: 0.8179 - val_loss: 0.6122 - val_accuracy: 0.7915
#
# Epoch 00040: val_accuracy improved from 0.78445 to 0.79152, saving model to mymodel2_40.h5
# Epoch 41/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4805 - accuracy: 0.8168 - val_loss: 0.5698 - val_accuracy: 0.7880
#
# Epoch 00041: val_accuracy did not improve from 0.79152
# Epoch 42/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4441 - accuracy: 0.8205 - val_loss: 0.5741 - val_accuracy: 0.7915
#
# Epoch 00042: val_accuracy did not improve from 0.79152
# Epoch 43/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4395 - accuracy: 0.8375 - val_loss: 0.5185 - val_accuracy: 0.7880
#
# Epoch 00043: val_accuracy did not improve from 0.79152
# Epoch 44/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.4488 - accuracy: 0.8373 - val_loss: 0.5504 - val_accuracy: 0.7951
#
# Epoch 00044: val_accuracy improved from 0.79152 to 0.79505, saving model to mymodel2_44.h5
# Epoch 45/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4650 - accuracy: 0.8220 - val_loss: 0.5497 - val_accuracy: 0.7951
#
# Epoch 00045: val_accuracy did not improve from 0.79505
# Epoch 46/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4613 - accuracy: 0.8411 - val_loss: 0.5194 - val_accuracy: 0.8092
#
# Epoch 00046: val_accuracy improved from 0.79505 to 0.80919, saving model to mymodel2_46.h5
# Epoch 47/200
# 9/9 [==============================] - 1s 69ms/step - loss: 0.4375 - accuracy: 0.8331 - val_loss: 0.5526 - val_accuracy: 0.7880
#
# Epoch 00047: val_accuracy did not improve from 0.80919
# Epoch 48/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4242 - accuracy: 0.8445 - val_loss: 0.5171 - val_accuracy: 0.8198
#
# Epoch 00048: val_accuracy improved from 0.80919 to 0.81979, saving model to mymodel2_48.h5
# Epoch 49/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.4110 - accuracy: 0.8375 - val_loss: 0.5060 - val_accuracy: 0.8092
#
# Epoch 00049: val_accuracy did not improve from 0.81979
# Epoch 50/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4225 - accuracy: 0.8363 - val_loss: 0.5038 - val_accuracy: 0.8057
#
# Epoch 00050: val_accuracy did not improve from 0.81979
# Epoch 51/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3959 - accuracy: 0.8429 - val_loss: 0.5203 - val_accuracy: 0.8092
#
# Epoch 00051: val_accuracy did not improve from 0.81979
# Epoch 52/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.3990 - accuracy: 0.8428 - val_loss: 0.4865 - val_accuracy: 0.7951
#
# Epoch 00052: val_accuracy did not improve from 0.81979
# Epoch 53/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4203 - accuracy: 0.8356 - val_loss: 0.5759 - val_accuracy: 0.7809
#
# Epoch 00053: val_accuracy did not improve from 0.81979
# Epoch 54/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.4803 - accuracy: 0.8183 - val_loss: 0.5409 - val_accuracy: 0.7915
#
# Epoch 00054: val_accuracy did not improve from 0.81979
# Epoch 55/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.4014 - accuracy: 0.8504 - val_loss: 0.5220 - val_accuracy: 0.8021
#
# Epoch 00055: val_accuracy did not improve from 0.81979
# Epoch 56/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3929 - accuracy: 0.8519 - val_loss: 0.5402 - val_accuracy: 0.8198
#
# Epoch 00056: val_accuracy did not improve from 0.81979
# Epoch 57/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.4235 - accuracy: 0.8321 - val_loss: 0.5093 - val_accuracy: 0.8092
#
# Epoch 00057: val_accuracy did not improve from 0.81979
# Epoch 58/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.3985 - accuracy: 0.8395 - val_loss: 0.4964 - val_accuracy: 0.7951
#
# Epoch 00058: val_accuracy did not improve from 0.81979
# Epoch 59/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3653 - accuracy: 0.8513 - val_loss: 0.5149 - val_accuracy: 0.7986
#
# Epoch 00059: val_accuracy did not improve from 0.81979
# Epoch 60/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3385 - accuracy: 0.8747 - val_loss: 0.4860 - val_accuracy: 0.7951
#
# Epoch 00060: val_accuracy did not improve from 0.81979
# Epoch 61/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3670 - accuracy: 0.8601 - val_loss: 0.4749 - val_accuracy: 0.8163
#
# Epoch 00061: val_accuracy did not improve from 0.81979
# Epoch 62/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3543 - accuracy: 0.8667 - val_loss: 0.5143 - val_accuracy: 0.7915
#
# Epoch 00062: val_accuracy did not improve from 0.81979
# Epoch 63/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3477 - accuracy: 0.8804 - val_loss: 0.4575 - val_accuracy: 0.7986
#
# Epoch 00063: val_accuracy did not improve from 0.81979
# Epoch 64/200
# 9/9 [==============================] - 1s 69ms/step - loss: 0.3372 - accuracy: 0.8702 - val_loss: 0.4559 - val_accuracy: 0.8092
#
# Epoch 00064: val_accuracy did not improve from 0.81979
# Epoch 65/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3473 - accuracy: 0.8636 - val_loss: 0.5240 - val_accuracy: 0.8163
#
# Epoch 00065: val_accuracy did not improve from 0.81979
# Epoch 66/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3271 - accuracy: 0.8662 - val_loss: 0.4641 - val_accuracy: 0.7986
#
# Epoch 00066: val_accuracy did not improve from 0.81979
# Epoch 67/200
# 9/9 [==============================] - 1s 82ms/step - loss: 0.3078 - accuracy: 0.8879 - val_loss: 0.4592 - val_accuracy: 0.8198
#
# Epoch 00067: val_accuracy did not improve from 0.81979
# Epoch 68/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3626 - accuracy: 0.8720 - val_loss: 0.4787 - val_accuracy: 0.8092
#
# Epoch 00068: val_accuracy did not improve from 0.81979
# Epoch 69/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3450 - accuracy: 0.8683 - val_loss: 0.4319 - val_accuracy: 0.8057
#
# Epoch 00069: val_accuracy did not improve from 0.81979
# Epoch 70/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.3161 - accuracy: 0.8868 - val_loss: 0.4274 - val_accuracy: 0.8127
#
# Epoch 00070: val_accuracy did not improve from 0.81979
# Epoch 71/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3254 - accuracy: 0.8788 - val_loss: 0.4272 - val_accuracy: 0.8163
#
# Epoch 00071: val_accuracy did not improve from 0.81979
# Epoch 72/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3024 - accuracy: 0.8673 - val_loss: 0.4668 - val_accuracy: 0.8092
#
# Epoch 00072: val_accuracy did not improve from 0.81979
# Epoch 73/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.3211 - accuracy: 0.8817 - val_loss: 0.4966 - val_accuracy: 0.8198
#
# Epoch 00073: val_accuracy did not improve from 0.81979
# Epoch 74/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2824 - accuracy: 0.8911 - val_loss: 0.5072 - val_accuracy: 0.8057
#
# Epoch 00074: val_accuracy did not improve from 0.81979
# Epoch 75/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.3233 - accuracy: 0.8777 - val_loss: 0.4366 - val_accuracy: 0.8092
#
# Epoch 00075: val_accuracy did not improve from 0.81979
# Epoch 76/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2725 - accuracy: 0.9055 - val_loss: 0.4985 - val_accuracy: 0.8163
#
# Epoch 00076: val_accuracy did not improve from 0.81979
# Epoch 77/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2932 - accuracy: 0.8881 - val_loss: 0.4724 - val_accuracy: 0.8057
#
# Epoch 00077: val_accuracy did not improve from 0.81979
# Epoch 78/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3028 - accuracy: 0.8774 - val_loss: 0.5116 - val_accuracy: 0.7986
#
# Epoch 00078: val_accuracy did not improve from 0.81979
# Epoch 79/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3204 - accuracy: 0.8752 - val_loss: 0.4658 - val_accuracy: 0.8198
#
# Epoch 00079: val_accuracy did not improve from 0.81979
# Epoch 80/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.3096 - accuracy: 0.8879 - val_loss: 0.4300 - val_accuracy: 0.8233
#
# Epoch 00080: val_accuracy improved from 0.81979 to 0.82332, saving model to mymodel2_80.h5
# Epoch 81/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.3222 - accuracy: 0.8839 - val_loss: 0.5082 - val_accuracy: 0.7915
#
# Epoch 00081: val_accuracy did not improve from 0.82332
# Epoch 82/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2782 - accuracy: 0.8988 - val_loss: 0.4194 - val_accuracy: 0.8375
#
# Epoch 00082: val_accuracy improved from 0.82332 to 0.83746, saving model to mymodel2_82.h5
# Epoch 83/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2669 - accuracy: 0.8981 - val_loss: 0.4202 - val_accuracy: 0.8269
#
# Epoch 00083: val_accuracy did not improve from 0.83746
# Epoch 84/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.3036 - accuracy: 0.8841 - val_loss: 0.4473 - val_accuracy: 0.8127
#
# Epoch 00084: val_accuracy did not improve from 0.83746
# Epoch 85/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2675 - accuracy: 0.8978 - val_loss: 0.4276 - val_accuracy: 0.8410
#
# Epoch 00085: val_accuracy improved from 0.83746 to 0.84099, saving model to mymodel2_85.h5
# Epoch 86/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2557 - accuracy: 0.9025 - val_loss: 0.4333 - val_accuracy: 0.8375
#
# Epoch 00086: val_accuracy did not improve from 0.84099
# Epoch 87/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2672 - accuracy: 0.8999 - val_loss: 0.5015 - val_accuracy: 0.8092
#
# Epoch 00087: val_accuracy did not improve from 0.84099
# Epoch 88/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2710 - accuracy: 0.8924 - val_loss: 0.4669 - val_accuracy: 0.8233
#
# Epoch 00088: val_accuracy did not improve from 0.84099
# Epoch 89/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2655 - accuracy: 0.8939 - val_loss: 0.4216 - val_accuracy: 0.8198
#
# Epoch 00089: val_accuracy did not improve from 0.84099
# Epoch 90/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2862 - accuracy: 0.8845 - val_loss: 0.3975 - val_accuracy: 0.8410
#
# Epoch 00090: val_accuracy did not improve from 0.84099
# Epoch 91/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2601 - accuracy: 0.8944 - val_loss: 0.4644 - val_accuracy: 0.8304
#
# Epoch 00091: val_accuracy did not improve from 0.84099
# Epoch 92/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2340 - accuracy: 0.9042 - val_loss: 0.4722 - val_accuracy: 0.8269
#
# Epoch 00092: val_accuracy did not improve from 0.84099
# Epoch 93/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2339 - accuracy: 0.9051 - val_loss: 0.4501 - val_accuracy: 0.8269
#
# Epoch 00093: val_accuracy did not improve from 0.84099
# Epoch 94/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2335 - accuracy: 0.9164 - val_loss: 0.4689 - val_accuracy: 0.8339
#
# Epoch 00094: val_accuracy did not improve from 0.84099
# Epoch 95/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2101 - accuracy: 0.9188 - val_loss: 0.4700 - val_accuracy: 0.8339
#
# Epoch 00095: val_accuracy did not improve from 0.84099
# Epoch 96/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2245 - accuracy: 0.9154 - val_loss: 0.4791 - val_accuracy: 0.8375
#
# Epoch 00096: val_accuracy did not improve from 0.84099
# Epoch 97/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2151 - accuracy: 0.9222 - val_loss: 0.4353 - val_accuracy: 0.8445
#
# Epoch 00097: val_accuracy improved from 0.84099 to 0.84452, saving model to mymodel2_97.h5
# Epoch 98/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2679 - accuracy: 0.8926 - val_loss: 0.4053 - val_accuracy: 0.8445
#
# Epoch 00098: val_accuracy did not improve from 0.84452
# Epoch 99/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2883 - accuracy: 0.8918 - val_loss: 0.4126 - val_accuracy: 0.8657
#
# Epoch 00099: val_accuracy improved from 0.84452 to 0.86572, saving model to mymodel2_99.h5
# Epoch 100/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2428 - accuracy: 0.9078 - val_loss: 0.3789 - val_accuracy: 0.8693
#
# Epoch 00100: val_accuracy improved from 0.86572 to 0.86926, saving model to mymodel2_100.h5
# Epoch 101/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2377 - accuracy: 0.9144 - val_loss: 0.4276 - val_accuracy: 0.8304
#
# Epoch 00101: val_accuracy did not improve from 0.86926
# Epoch 102/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.2380 - accuracy: 0.9161 - val_loss: 0.3751 - val_accuracy: 0.8551
#
# Epoch 00102: val_accuracy did not improve from 0.86926
# Epoch 103/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2374 - accuracy: 0.9092 - val_loss: 0.4026 - val_accuracy: 0.8375
#
# Epoch 00103: val_accuracy did not improve from 0.86926
# Epoch 104/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2404 - accuracy: 0.9111 - val_loss: 0.4601 - val_accuracy: 0.8481
#
# Epoch 00104: val_accuracy did not improve from 0.86926
# Epoch 105/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2032 - accuracy: 0.9300 - val_loss: 0.4542 - val_accuracy: 0.8304
#
# Epoch 00105: val_accuracy did not improve from 0.86926
# Epoch 106/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1988 - accuracy: 0.9177 - val_loss: 0.3989 - val_accuracy: 0.8622
#
# Epoch 00106: val_accuracy did not improve from 0.86926
# Epoch 107/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.2044 - accuracy: 0.9201 - val_loss: 0.5194 - val_accuracy: 0.8339
#
# Epoch 00107: val_accuracy did not improve from 0.86926
# Epoch 108/200
# 9/9 [==============================] - 1s 70ms/step - loss: 0.1991 - accuracy: 0.9233 - val_loss: 0.4606 - val_accuracy: 0.8410
#
# Epoch 00108: val_accuracy did not improve from 0.86926
# Epoch 109/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1868 - accuracy: 0.9286 - val_loss: 0.5004 - val_accuracy: 0.8375
#
# Epoch 00109: val_accuracy did not improve from 0.86926
# Epoch 110/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2130 - accuracy: 0.9157 - val_loss: 0.3976 - val_accuracy: 0.8657
#
# Epoch 00110: val_accuracy did not improve from 0.86926
# Epoch 111/200
# 9/9 [==============================] - 1s 84ms/step - loss: 0.2039 - accuracy: 0.9107 - val_loss: 0.3697 - val_accuracy: 0.8693
#
# Epoch 00111: val_accuracy did not improve from 0.86926
# Epoch 112/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1879 - accuracy: 0.9306 - val_loss: 0.3838 - val_accuracy: 0.8622
#
# Epoch 00112: val_accuracy did not improve from 0.86926
# Epoch 113/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.1969 - accuracy: 0.9255 - val_loss: 0.3342 - val_accuracy: 0.8657
#
# Epoch 00113: val_accuracy did not improve from 0.86926
# Epoch 114/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1731 - accuracy: 0.9436 - val_loss: 0.3877 - val_accuracy: 0.8622
#
# Epoch 00114: val_accuracy did not improve from 0.86926
# Epoch 115/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.1896 - accuracy: 0.9324 - val_loss: 0.3759 - val_accuracy: 0.8551
#
# Epoch 00115: val_accuracy did not improve from 0.86926
# Epoch 116/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1820 - accuracy: 0.9280 - val_loss: 0.3364 - val_accuracy: 0.8728
#
# Epoch 00116: val_accuracy improved from 0.86926 to 0.87279, saving model to mymodel2_116.h5
# Epoch 117/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1721 - accuracy: 0.9336 - val_loss: 0.3681 - val_accuracy: 0.8622
#
# Epoch 00117: val_accuracy did not improve from 0.87279
# Epoch 118/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1832 - accuracy: 0.9310 - val_loss: 0.3934 - val_accuracy: 0.8551
#
# Epoch 00118: val_accuracy did not improve from 0.87279
# Epoch 119/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.2075 - accuracy: 0.9205 - val_loss: 0.3843 - val_accuracy: 0.8481
#
# Epoch 00119: val_accuracy did not improve from 0.87279
# Epoch 120/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1787 - accuracy: 0.9437 - val_loss: 0.3601 - val_accuracy: 0.8693
#
# Epoch 00120: val_accuracy did not improve from 0.87279
# Epoch 121/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1819 - accuracy: 0.9255 - val_loss: 0.3591 - val_accuracy: 0.8657
#
# Epoch 00121: val_accuracy did not improve from 0.87279
# Epoch 122/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1614 - accuracy: 0.9344 - val_loss: 0.3759 - val_accuracy: 0.8657
#
# Epoch 00122: val_accuracy did not improve from 0.87279
# Epoch 123/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1698 - accuracy: 0.9364 - val_loss: 0.4257 - val_accuracy: 0.8410
#
# Epoch 00123: val_accuracy did not improve from 0.87279
# Epoch 124/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1815 - accuracy: 0.9392 - val_loss: 0.3957 - val_accuracy: 0.8481
#
# Epoch 00124: val_accuracy did not improve from 0.87279
# Epoch 125/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1819 - accuracy: 0.9143 - val_loss: 0.3772 - val_accuracy: 0.8516
#
# Epoch 00125: val_accuracy did not improve from 0.87279
# Epoch 126/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1635 - accuracy: 0.9412 - val_loss: 0.3815 - val_accuracy: 0.8693
#
# Epoch 00126: val_accuracy did not improve from 0.87279
# Epoch 127/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1288 - accuracy: 0.9640 - val_loss: 0.3504 - val_accuracy: 0.8728
#
# Epoch 00127: val_accuracy did not improve from 0.87279
# Epoch 128/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1486 - accuracy: 0.9481 - val_loss: 0.3500 - val_accuracy: 0.8763
#
# Epoch 00128: val_accuracy improved from 0.87279 to 0.87633, saving model to mymodel2_128.h5
# Epoch 129/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1389 - accuracy: 0.9499 - val_loss: 0.4225 - val_accuracy: 0.8587
#
# Epoch 00129: val_accuracy did not improve from 0.87633
# Epoch 130/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.1468 - accuracy: 0.9416 - val_loss: 0.4402 - val_accuracy: 0.8516
#
# Epoch 00130: val_accuracy did not improve from 0.87633
# Epoch 131/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1725 - accuracy: 0.9239 - val_loss: 0.5680 - val_accuracy: 0.8481
#
# Epoch 00131: val_accuracy did not improve from 0.87633
# Epoch 132/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1778 - accuracy: 0.9353 - val_loss: 0.4551 - val_accuracy: 0.8481
#
# Epoch 00132: val_accuracy did not improve from 0.87633
# Epoch 133/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1550 - accuracy: 0.9405 - val_loss: 0.4203 - val_accuracy: 0.8410
#
# Epoch 00133: val_accuracy did not improve from 0.87633
# Epoch 134/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1896 - accuracy: 0.9295 - val_loss: 0.3479 - val_accuracy: 0.8693
#
# Epoch 00134: val_accuracy did not improve from 0.87633
# Epoch 135/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1656 - accuracy: 0.9383 - val_loss: 0.3715 - val_accuracy: 0.8693
#
# Epoch 00135: val_accuracy did not improve from 0.87633
# Epoch 136/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1480 - accuracy: 0.9404 - val_loss: 0.3456 - val_accuracy: 0.8869
#
# Epoch 00136: val_accuracy improved from 0.87633 to 0.88693, saving model to mymodel2_136.h5
# Epoch 137/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1460 - accuracy: 0.9427 - val_loss: 0.3628 - val_accuracy: 0.8728
#
# Epoch 00137: val_accuracy did not improve from 0.88693
# Epoch 138/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1394 - accuracy: 0.9550 - val_loss: 0.3450 - val_accuracy: 0.8728
#
# Epoch 00138: val_accuracy did not improve from 0.88693
# Epoch 139/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1422 - accuracy: 0.9496 - val_loss: 0.3489 - val_accuracy: 0.8763
#
# Epoch 00139: val_accuracy did not improve from 0.88693
# Epoch 140/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1268 - accuracy: 0.9595 - val_loss: 0.3581 - val_accuracy: 0.8728
#
# Epoch 00140: val_accuracy did not improve from 0.88693
# Epoch 141/200
# 9/9 [==============================] - 1s 71ms/step - loss: 0.1408 - accuracy: 0.9478 - val_loss: 0.3406 - val_accuracy: 0.8834
#
# Epoch 00141: val_accuracy did not improve from 0.88693
# Epoch 142/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1576 - accuracy: 0.9339 - val_loss: 0.4830 - val_accuracy: 0.8516
#
# Epoch 00142: val_accuracy did not improve from 0.88693
# Epoch 143/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1298 - accuracy: 0.9493 - val_loss: 0.4248 - val_accuracy: 0.8551
#
# Epoch 00143: val_accuracy did not improve from 0.88693
# Epoch 144/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1375 - accuracy: 0.9493 - val_loss: 0.4590 - val_accuracy: 0.8445
#
# Epoch 00144: val_accuracy did not improve from 0.88693
# Epoch 145/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1304 - accuracy: 0.9580 - val_loss: 0.4010 - val_accuracy: 0.8587
#
# Epoch 00145: val_accuracy did not improve from 0.88693
# Epoch 146/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1685 - accuracy: 0.9308 - val_loss: 0.4017 - val_accuracy: 0.8622
#
# Epoch 00146: val_accuracy did not improve from 0.88693
# Epoch 147/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1422 - accuracy: 0.9390 - val_loss: 0.4376 - val_accuracy: 0.8445
#
# Epoch 00147: val_accuracy did not improve from 0.88693
# Epoch 148/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1255 - accuracy: 0.9526 - val_loss: 0.4300 - val_accuracy: 0.8445
#
# Epoch 00148: val_accuracy did not improve from 0.88693
# Epoch 149/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1115 - accuracy: 0.9588 - val_loss: 0.3707 - val_accuracy: 0.8693
#
# Epoch 00149: val_accuracy did not improve from 0.88693
# Epoch 150/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1244 - accuracy: 0.9474 - val_loss: 0.3474 - val_accuracy: 0.8728
#
# Epoch 00150: val_accuracy did not improve from 0.88693
# Epoch 151/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1354 - accuracy: 0.9428 - val_loss: 0.3172 - val_accuracy: 0.8834
#
# Epoch 00151: val_accuracy did not improve from 0.88693
# Epoch 152/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1073 - accuracy: 0.9648 - val_loss: 0.3992 - val_accuracy: 0.8763
#
# Epoch 00152: val_accuracy did not improve from 0.88693
# Epoch 153/200
# 9/9 [==============================] - 1s 84ms/step - loss: 0.1400 - accuracy: 0.9481 - val_loss: 0.4769 - val_accuracy: 0.8410
#
# Epoch 00153: val_accuracy did not improve from 0.88693
# Epoch 154/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1229 - accuracy: 0.9599 - val_loss: 0.3472 - val_accuracy: 0.8763
#
# Epoch 00154: val_accuracy did not improve from 0.88693
# Epoch 155/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1017 - accuracy: 0.9699 - val_loss: 0.3872 - val_accuracy: 0.8693
#
# Epoch 00155: val_accuracy did not improve from 0.88693
# Epoch 156/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1172 - accuracy: 0.9566 - val_loss: 0.3681 - val_accuracy: 0.8551
#
# Epoch 00156: val_accuracy did not improve from 0.88693
# Epoch 157/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1127 - accuracy: 0.9587 - val_loss: 0.4447 - val_accuracy: 0.8410
#
# Epoch 00157: val_accuracy did not improve from 0.88693
# Epoch 158/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1436 - accuracy: 0.9467 - val_loss: 0.4983 - val_accuracy: 0.8587
#
# Epoch 00158: val_accuracy did not improve from 0.88693
# Epoch 159/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1237 - accuracy: 0.9568 - val_loss: 0.4330 - val_accuracy: 0.8445
#
# Epoch 00159: val_accuracy did not improve from 0.88693
# Epoch 160/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1352 - accuracy: 0.9475 - val_loss: 0.5608 - val_accuracy: 0.8445
#
# Epoch 00160: val_accuracy did not improve from 0.88693
# Epoch 161/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1479 - accuracy: 0.9467 - val_loss: 0.5031 - val_accuracy: 0.8445
#
# Epoch 00161: val_accuracy did not improve from 0.88693
# Epoch 162/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1349 - accuracy: 0.9442 - val_loss: 0.3886 - val_accuracy: 0.8763
#
# Epoch 00162: val_accuracy did not improve from 0.88693
# Epoch 163/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1214 - accuracy: 0.9667 - val_loss: 0.3424 - val_accuracy: 0.8763
#
# Epoch 00163: val_accuracy did not improve from 0.88693
# Epoch 164/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0842 - accuracy: 0.9743 - val_loss: 0.4002 - val_accuracy: 0.8657
#
# Epoch 00164: val_accuracy did not improve from 0.88693
# Epoch 165/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.1012 - accuracy: 0.9634 - val_loss: 0.4546 - val_accuracy: 0.8551
#
# Epoch 00165: val_accuracy did not improve from 0.88693
# Epoch 166/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1061 - accuracy: 0.9653 - val_loss: 0.4474 - val_accuracy: 0.8481
#
# Epoch 00166: val_accuracy did not improve from 0.88693
# Epoch 167/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1242 - accuracy: 0.9493 - val_loss: 0.3835 - val_accuracy: 0.8693
#
# Epoch 00167: val_accuracy did not improve from 0.88693
# Epoch 168/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1015 - accuracy: 0.9596 - val_loss: 0.4016 - val_accuracy: 0.8551
#
# Epoch 00168: val_accuracy did not improve from 0.88693
# Epoch 169/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1594 - accuracy: 0.9434 - val_loss: 0.3474 - val_accuracy: 0.8799
#
# Epoch 00169: val_accuracy did not improve from 0.88693
# Epoch 170/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.1179 - accuracy: 0.9533 - val_loss: 0.3715 - val_accuracy: 0.8763
#
# Epoch 00170: val_accuracy did not improve from 0.88693
# Epoch 171/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1146 - accuracy: 0.9590 - val_loss: 0.3134 - val_accuracy: 0.8905
#
# Epoch 00171: val_accuracy improved from 0.88693 to 0.89046, saving model to mymodel2_171.h5
# Epoch 172/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.1244 - accuracy: 0.9484 - val_loss: 0.2760 - val_accuracy: 0.8869
#
# Epoch 00172: val_accuracy did not improve from 0.89046
# Epoch 173/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.1067 - accuracy: 0.9672 - val_loss: 0.2706 - val_accuracy: 0.8975
#
# Epoch 00173: val_accuracy improved from 0.89046 to 0.89753, saving model to mymodel2_173.h5
# Epoch 174/200
# 9/9 [==============================] - 1s 77ms/step - loss: 0.0923 - accuracy: 0.9779 - val_loss: 0.3150 - val_accuracy: 0.8763
#
# Epoch 00174: val_accuracy did not improve from 0.89753
# Epoch 175/200
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0884 - accuracy: 0.9709 - val_loss: 0.3651 - val_accuracy: 0.8834
#
# Epoch 00175: val_accuracy did not improve from 0.89753
# Epoch 176/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0805 - accuracy: 0.9756 - val_loss: 0.3173 - val_accuracy: 0.8799
#
# Epoch 00176: val_accuracy did not improve from 0.89753
# Epoch 177/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0949 - accuracy: 0.9618 - val_loss: 0.3586 - val_accuracy: 0.8799
#
# Epoch 00177: val_accuracy did not improve from 0.89753
# Epoch 178/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0819 - accuracy: 0.9719 - val_loss: 0.3826 - val_accuracy: 0.8799
#
# Epoch 00178: val_accuracy did not improve from 0.89753
# Epoch 179/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0773 - accuracy: 0.9686 - val_loss: 0.3470 - val_accuracy: 0.8834
#
# Epoch 00179: val_accuracy did not improve from 0.89753
# Epoch 180/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0649 - accuracy: 0.9797 - val_loss: 0.3703 - val_accuracy: 0.8834
#
# Epoch 00180: val_accuracy did not improve from 0.89753
# Epoch 181/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0698 - accuracy: 0.9734 - val_loss: 0.3696 - val_accuracy: 0.8834
#
# Epoch 00181: val_accuracy did not improve from 0.89753
# Epoch 182/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0937 - accuracy: 0.9678 - val_loss: 0.3280 - val_accuracy: 0.8799
#
# Epoch 00182: val_accuracy did not improve from 0.89753
# Epoch 183/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0755 - accuracy: 0.9764 - val_loss: 0.2989 - val_accuracy: 0.8940
#
# Epoch 00183: val_accuracy did not improve from 0.89753
# Epoch 184/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0863 - accuracy: 0.9662 - val_loss: 0.2978 - val_accuracy: 0.8940
#
# Epoch 00184: val_accuracy did not improve from 0.89753
# Epoch 185/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0835 - accuracy: 0.9705 - val_loss: 0.3580 - val_accuracy: 0.8799
#
# Epoch 00185: val_accuracy did not improve from 0.89753
# Epoch 186/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0783 - accuracy: 0.9688 - val_loss: 0.3047 - val_accuracy: 0.8834
#
# Epoch 00186: val_accuracy did not improve from 0.89753
# Epoch 187/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0697 - accuracy: 0.9766 - val_loss: 0.2756 - val_accuracy: 0.8975
#
# Epoch 00187: val_accuracy did not improve from 0.89753
# Epoch 188/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0716 - accuracy: 0.9702 - val_loss: 0.3255 - val_accuracy: 0.8940
#
# Epoch 00188: val_accuracy did not improve from 0.89753
# Epoch 189/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0806 - accuracy: 0.9760 - val_loss: 0.4087 - val_accuracy: 0.8763
#
# Epoch 00189: val_accuracy did not improve from 0.89753
# Epoch 190/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0821 - accuracy: 0.9721 - val_loss: 0.4016 - val_accuracy: 0.8799
#
# Epoch 00190: val_accuracy did not improve from 0.89753
# Epoch 191/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0741 - accuracy: 0.9783 - val_loss: 0.3559 - val_accuracy: 0.8905
#
# Epoch 00191: val_accuracy did not improve from 0.89753
# Epoch 192/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0744 - accuracy: 0.9749 - val_loss: 0.3046 - val_accuracy: 0.8975
#
# Epoch 00192: val_accuracy did not improve from 0.89753
# Epoch 193/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0592 - accuracy: 0.9859 - val_loss: 0.3103 - val_accuracy: 0.8940
#
# Epoch 00193: val_accuracy did not improve from 0.89753
# Epoch 194/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0760 - accuracy: 0.9688 - val_loss: 0.3062 - val_accuracy: 0.8975
#
# Epoch 00194: val_accuracy did not improve from 0.89753
# Epoch 195/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0696 - accuracy: 0.9793 - val_loss: 0.3806 - val_accuracy: 0.8763
#
# Epoch 00195: val_accuracy did not improve from 0.89753
# Epoch 196/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0829 - accuracy: 0.9657 - val_loss: 0.4222 - val_accuracy: 0.8728
#
# Epoch 00196: val_accuracy did not improve from 0.89753
# Epoch 197/200
# 9/9 [==============================] - 1s 76ms/step - loss: 0.1131 - accuracy: 0.9596 - val_loss: 0.3650 - val_accuracy: 0.8834
#
# Epoch 00197: val_accuracy did not improve from 0.89753
# Epoch 198/200
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0931 - accuracy: 0.9657 - val_loss: 0.3769 - val_accuracy: 0.8799
#
# Epoch 00198: val_accuracy did not improve from 0.89753
# Epoch 199/200
# 9/9 [==============================] - 1s 74ms/step - loss: 0.0994 - accuracy: 0.9612 - val_loss: 0.3242 - val_accuracy: 0.8869
#
# Epoch 00199: val_accuracy did not improve from 0.89753
# Epoch 200/200
# 9/9 [==============================] - 1s 73ms/step - loss: 0.0887 - accuracy: 0.9645 - val_loss: 0.2439 - val_accuracy: 0.9081
#
# Epoch 00200: val_accuracy improved from 0.89753 to 0.90813, saving model to mymodel2_200.h5

# %%
y_pred
# Out:
# array([[2.6549864e-13, 2.9095138e-14, 1.0000000e+00, 1.5817884e-17,
#         4.6442364e-12, 4.3313491e-12],
#        [8.5715670e-05, 3.7461244e-02, 2.8991888e-04, 6.6806144e-01,
#         5.6669872e-02, 2.3743181e-01],
#        [8.8034256e-04, 2.0858583e-06, 9.6243727e-01, 3.2777985e-05,
#         3.6365189e-02, 2.8233347e-04],
#        ...,
#        [1.2774878e-08, 2.6778962e-14, 9.9999988e-01, 3.0139612e-13,
#         9.3785196e-08, 1.6301464e-12],
#        [3.1182545e-03, 6.4535829e-04, 2.1052184e-03, 4.3839607e-01,
#         4.2261240e-01, 1.3312268e-01],
#        [8.5843325e-01, 7.5429557e-06, 2.5127307e-04, 2.9250003e-07,
#         1.4122856e-01, 7.9144280e-05]], dtype=float32)

# %%
y_pred=model.predict_classes(np.expand_dims(x_train, axis=3))
rounded_labels=np.argmax(y_train, axis=1)
con_mat = confusion_matrix(rounded_labels, y_pred)
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm, index = classes, columns = classes)
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
y_pred=model.predict_classes(np.expand_dims(x_test, axis=3))
rounded_labels=np.argmax(y_test, axis=1)
con_mat = confusion_matrix(rounded_labels, y_pred)
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
con_mat_df = pd.DataFrame(con_mat_norm, index = classes, columns = classes)
figure = plt.figure(figsize=(8, 8))
sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
model.save('/content/drive/My Drive/ISEP/A3/DEEP LEARNING/Respiration Sound/model_with stretched_data.h5', save_format='h5')

# %%
model = load_model('/content/drive/My Drive/ISEP/A3/DEEP LEARNING/Respiration Sound/model.h5')
